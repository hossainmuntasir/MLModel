# %% [markdown]
# <a href="https://colab.research.google.com/github/hossainmuntasir/MLModel/blob/main/Building.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Load**

# %% [markdown]
# ### **Loading the first dataset**

# %%
import pandas as pd
import requests
from io import StringIO

file_id = '1zW60eJEkUQ5xSaiTyReKqorl-71MoJCJ'
direct_link = f'https://drive.google.com/uc?id={file_id}'

response = requests.get(direct_link)

if response.status_code == 200:
    data = StringIO(response.text)
    df11 = pd.read_csv(data)
else:
    print(f"Failed to download the file. Status code: {response.status_code}")
# Out:
# <ipython-input-20-b70ff9128acb>:12: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df11 = pd.read_csv(data)

# %%
df11
# Out:
#        Zone name                 Time Zone temperature (degree Celsius)  \
# 0           G-05  2023-08-01 00:10:32                                20
# 1           G-02  2023-08-01 00:10:32                                19
# 2          L1-02  2023-08-01 00:10:32                             20.25
# 3          L1-03  2023-08-01 00:10:32                                21
# 4          L1-04  2023-08-01 00:10:32                             21.25
# ...          ...                  ...                               ...
# 893935   Zone-27  2024-01-27 23:40:09                                 -
# 893936   Zone-28  2024-01-27 23:40:09                                 -
# 893937      R-01  2024-01-27 23:40:09                                 -
# 893938      R-02  2024-01-27 23:40:09                                 -
# 893939      R-03  2024-01-27 23:40:09                                 -
#
#        Slab temperature (degree Celsius)  \
# 0                                  20.56
# ...

# %% [markdown]
# ### **Loading the second dataset**

# %%
file_id = '1lfjsnD8Rjuok3-DwFI4NKjI3q47Tbyyn'
direct_link = f'https://drive.google.com/uc?id={file_id}'

response = requests.get(direct_link)

if response.status_code == 200:
    data = StringIO(response.text)
    df12 = pd.read_csv(data)
else:
    print(f"Failed to download the file. Status code: {response.status_code}")

# %%
df12
# Out:
#         Zone name                 Time Zone temperature (degree Celsius)  \
# 0            G-05  2023-01-01 00:02:41                                23
# 1            G-02  2023-01-01 00:02:41                                23
# 2           L1-02  2023-01-01 00:02:41                             26.25
# 3           L1-03  2023-01-01 00:02:41                              25.5
# 4           L1-04  2023-01-01 00:02:41                             26.25
# ...           ...                  ...                               ...
# 1048570      G-05  2023-08-12 07:16:01                                18
# 1048571      G-02  2023-08-12 07:16:01                                18
# 1048572     L1-02  2023-08-12 07:16:01                              18.5
# 1048573     L1-03  2023-08-12 07:16:01                              19.5
# 1048574     L1-04  2023-08-12 07:16:01                                20
#
#         Slab temperature (degree Celsius)  \
# 0                                   21.73
# ...

# %% [markdown]
# ## **Combine Building 1 datasets**

# %%
building1 = pd.concat([df11, df12], ignore_index=True)

# %%
building1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1942515 entries, 0 to 1942514
# Data columns (total 10 columns):
#  #   Column                                    Dtype
# ---  ------                                    -----
#  0   Zone name                                 object
#  1   Time                                      object
#  2   Zone temperature (degree Celsius)         object
#  3   Slab temperature (degree Celsius)         object
#  4   Dew point temperature (degree Celsius)    object
#  5   Outside air temperature (degree Celsius)  object
#  6   Zone CO2 (ppm)                            object
#  7   Damper status                             object
#  8   Louver status                             object
#  9   Fan status                                object
# dtypes: object(10)
# memory usage: 148.2+ MB

# %% [markdown]
# ### **Load Building two dataset**

# %%
file_id = '1DRysOS7kMkKfxhyLu2AS7bQHZjoNdTDj'
direct_link = f'https://drive.google.com/uc?id={file_id}'

response = requests.get(direct_link)

if response.status_code == 200:
    data = StringIO(response.text)
    df20 = pd.read_csv(data)
else:
    print(f"Failed to download the file. Status code: {response.status_code}")
# Out:
# <ipython-input-26-8d49d8eba0f8>:8: DtypeWarning: Columns (4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df20 = pd.read_csv(data)

# %%
b
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520938 entries, 0 to 520937
# Data columns (total 8 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Zone name                                 520938 non-null  object
#  1   Time                                      520938 non-null  object
#  2   Zone temperature (degree Celsius)         520938 non-null  object
#  3   Slab temperature (degree Celsius)         520938 non-null  object
#  4   Dew point temperature (degree Celsius)    520938 non-null  object
#  5   Outside air temperature (degree Celsius)  520938 non-null  object
#  6   Zone CO2 (ppm)                            520938 non-null  object
#  7   Fan status                                520938 non-null  object
# dtypes: object(8)
# memory usage: 31.8+ MB

# %%
building2 = df20

# %%
building2
# Out:
#        Zone name                 Time Zone temperature (degree Celsius)  \
# 0          Plant  2023-03-27 21:34:59                                 -
# 1         Zone-1  2023-03-27 21:34:59                                 -
# 2         Zone-2  2023-03-27 21:34:59                                 -
# 3          Plant  2023-03-27 21:34:59                                 -
# 4          Plant  2023-03-27 21:34:59                                 -
# ...          ...                  ...                               ...
# 520933    Mf-2-1  2024-04-03 09:25:08                                 -
# 520934    Ac-2-2  2024-04-03 09:25:08                                 -
# 520935    Ac-2-3  2024-04-03 09:25:08                                 -
# 520936    Ac-2-4  2024-04-03 09:25:08                                 -
# 520937    Ac-2-5  2024-04-03 09:25:08                                 -
#
#        Slab temperature (degree Celsius)  \
# 0                                      -
# ...

# %% [markdown]
# ## **Load Building three datasets**

# %%
file_id = '1NTxpVn_stsXNqfnHbwmH1RbqJW5quJWU'
direct_link = f'https://drive.google.com/uc?id={file_id}'

response = requests.get(direct_link)

if response.status_code == 200:
    data = StringIO(response.text)
    df31 = pd.read_csv(data)
else:
    print(f"Failed to download the file. Status code: {response.status_code}")
# Out:
# <ipython-input-31-71a735fb3509>:8: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df31 = pd.read_csv(data)

# %%
file_id = '1wvxsT94E6gi6Oj1AaSsrGhxYHmaY7ToI'
direct_link = f'https://drive.google.com/uc?id={file_id}'

response = requests.get(direct_link)

if response.status_code == 200:
    data = StringIO(response.text)
    df32 = pd.read_csv(data)
else:
    print(f"Failed to download the file. Status code: {response.status_code}")
# Out:
# <ipython-input-32-dd8b7816ed8e>:8: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df32 = pd.read_csv(data)

# %%
building3 = pd.concat([df31, df32], ignore_index=True)

# %%
building3
# Out:
#         Zone name                 Time Zone temperature (degree Celsius)  \
# 0          Acu101  2023-09-25 00:05:08                              22.1
# 1          Acu102  2023-09-25 00:05:08                              21.7
# 2          Acu103  2023-09-25 00:05:08                              20.1
# 3          Acu104  2023-09-25 00:05:08                              20.5
# 4          Acu105  2023-09-25 00:05:08                              20.5
# ...           ...                  ...                               ...
# 2097145    Acu308  2023-09-25 05:45:13                              19.3
# 2097146     Pac43  2023-09-25 05:45:13                             23.64
# 2097147     Plant  2023-09-25 05:45:13                                 -
# 2097148     Pac41  2023-09-25 05:45:13                                 -
# 2097149     Pac42  2023-09-25 05:45:13                                 -
#
#         Slab temperature (degree Celsius)  \
# 0                                       -
# ...

# %%
building1_len = len(building1)
building2_len = len(building2)
building3_len = len(building3)

# %%
print(f"BUilding 1 {building1_len}, Building 2 {building2_len}, Building 3 {building3_len}")
# Out:
# BUilding 1 1942515, Building 2 520938, Building 3 2097150

# %%
import matplotlib.pyplot as plt


# Data for plotting
buildings = ['Building 1', 'Building 2', 'Building 3']
lengths = [building1_len, building2_len, building3_len]

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(buildings, lengths, color=['blue', 'green', 'red'])
plt.xlabel('Building')
plt.ylabel('Number of Rows (Data Points) in millions')
plt.title('Comparison of Data Points Across Three Buildings')
plt.show()
